# %%
import pandas as pd

# %%
netID = "jsc9862"

df_merged = pd.read_csv(f"/scratch/{netID}/Explaining_Song_Popularity/merged_df_with_ids.csv")
df_links = pd.read_csv(f"/scratch/{netID}/Explaining_Song_Popularity/apple_music_matches.csv")

# %%
final_df = df_merged.merge(
    df_links[["song_id", "preview_url", "query_title", "query_artist", "track_id", "track_view_url"]],
    on="song_id",
    how="left"
)

final_df = final_df[["song_id", "title", "artist", "query_title", "query_artist", "track_genre", "popularity", "lyrics", "preview_url", "track_id", "track_view_url"]]
final_df = final_df.dropna(subset=["preview_url", "lyrics"])
final_df['track_id'] = final_df['track_id'].astype(int)

final_df.head()
# Out:
#    song_id              title                 artist        query_title  \
# 0        0     Mr. Brightside            The Killers      mr brightside
# 1        1    Californication  Red Hot Chili Peppers    californication
# 2        2  Seven Nation Army      The White Stripes  seven nation army
# 3        3           All Star            Smash Mouth           all star
# 4        4  Where Is My Mind?                 Pixies   where is my mind
#
#             query_artist track_genre  popularity  \
# 0            the killers    alt-rock         2.0
# 1  red hot chili peppers    alt-rock         2.0
# 2      the white stripes    alt-rock        84.0
# 3            smash mouth    alt-rock         0.0
# 4                 pixies    alt-rock        77.0
#
#                                               lyrics  \
# 0  [Verse]\nComing out of my cage and I've been d...
# 1  [Verse 1]\nPsychic spies from China try to ste...
# 2  [Verse 1]\nI'm gonna fight 'em off\nA seven na...
# 3  [Verse 1]\nSomebody once told me the world is ...
# 4  [Intro: Black Francis, Kim Deal]\nOoh—stop\n\n...
#
#                                          preview_url    track_id  \
# 0  https://audio-ssl.itunes.apple.com/itunes-asse...  1440891171
# 1  https://audio-ssl.itunes.apple.com/itunes-asse...   947688104
# 2  https://audio-ssl.itunes.apple.com/itunes-asse...  1533513537
# 3  https://audio-ssl.itunes.apple.com/itunes-asse...  1440915693
# 4  https://audio-ssl.itunes.apple.com/itunes-asse...  1027465608
#
#                                       track_view_url
# 0  https://music.apple.com/us/album/mr-brightside...
# 1  https://music.apple.com/us/album/californicati...
# 2  https://music.apple.com/us/album/seven-nation-...
# 3  https://music.apple.com/us/album/all-star/1440...
# 4  https://music.apple.com/us/album/where-is-my-m...
